# %%
# import dask as dd
import matplotlib.pyplot as plt 
import pandas as pd
import pandas_bokeh

from pathlib import Path
from re import match
from typing import Tuple

pd.set_option('plotting.backend', 'pandas_bokeh')
pandas_bokeh.output_notebook()

# plt.rcParams["figure.figsize"] = (30, 12)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
tsad = Path("datasets/AnomalyDatasets_2021/UCR_TimeSeriesAnomalyDatasets2021/FilesAreInHere/UCR_Anomaly_FullData/")

# %%
files_df = pd.DataFrame(map(str, tsad.glob("*")), columns=["path"])

files_df["filename"] = files_df.path.str.split("/").str[-1]

files_df[["file_number", "mnemonic", "training_end", "anomaly_start", "anomaly_end"]] = files_df.filename.str.extract("([0-9]+)_UCR_Anomaly_([A-Za-z0-9]+)_([0-9]+)_([0-9]+)_([0-9]+).txt")

files_df = files_df.set_index("file_number").sort_index()

# %%
files_df
# Out:
#                                                           path  \
# file_number
# 001          datasets/AnomalyDatasets_2021/UCR_TimeSeriesAn...
# 002          datasets/AnomalyDatasets_2021/UCR_TimeSeriesAn...
# 003          datasets/AnomalyDatasets_2021/UCR_TimeSeriesAn...
# 004          datasets/AnomalyDatasets_2021/UCR_TimeSeriesAn...
# 005          datasets/AnomalyDatasets_2021/UCR_TimeSeriesAn...
# ...                                                        ...
# 246          datasets/AnomalyDatasets_2021/UCR_TimeSeriesAn...
# 247          datasets/AnomalyDatasets_2021/UCR_TimeSeriesAn...
# 248          datasets/AnomalyDatasets_2021/UCR_TimeSeriesAn...
# 249          datasets/AnomalyDatasets_2021/UCR_TimeSeriesAn...
# 250          datasets/AnomalyDatasets_2021/UCR_TimeSeriesAn...
#
#                                                       filename  \
# file_number
# 001          001_UCR_Anomaly_DISTORTED1sddb40_35000_52000_5...
# 002          002_UCR_Anomaly_DISTORTED2sddb40_35000_56600_5...
# 003          003_UCR_Anomaly_DISTORTED3sddb40_35000_46600_4...
# 004          004_UCR_Anomaly_DISTORTEDBIDMC1_2500_5400_5600...
# 005          005_UCR_Anomaly_DISTORTEDCIMIS44AirTemperature...
# ...                                                        ...
# 246          246_UCR_Anomaly_tilt12755mtable_100211_270800_...
# 247          247_UCR_Anomaly_tilt12755mtable_50211_121900_1...
# 248               248_UCR_Anomaly_weallwalk_2000_4702_4707.txt
# 249               249_UCR_Anomaly_weallwalk_2753_8285_8315.txt
# 250               250_UCR_Anomaly_weallwalk_2951_7290_7296.txt
#
#                                     mnemonic training_end anomaly_start  \
# file_number
# 001                         DISTORTED1sddb40        35000         52000
# 002                         DISTORTED2sddb40        35000         56600
# 003                         DISTORTED3sddb40        35000         46600
# 004                          DISTORTEDBIDMC1         2500          5400
# 005          DISTORTEDCIMIS44AirTemperature1         4000          5391
# ...                                      ...          ...           ...
# 246                          tilt12755mtable       100211        270800
# 247                          tilt12755mtable        50211        121900
# 248                                weallwalk         2000          4702
# 249                                weallwalk         2753          8285
# 250                                weallwalk         2951          7290
#
#             anomaly_end
# file_number
# 001               52620
# 002               56900
# 003               46900
# 004                5600
# 005                5392
# ...                 ...
# 246              271070
# 247              121980
# 248                4707
# 249                8315
# 250                7296
#
# [250 rows x 6 columns]

# %%
files_fix = {204, 205, 206, 207, 208, 225, 226, 242, 243}

# %%
for i, p in enumerate(sorted(tsad.glob("*")), 1):
    if i not in files_fix: continue
    df = pd.read_csv(str(p), header=None, delim_whitespace=i in files_fix)
    
    if i in files_fix: df = df.T
    
    df = df.rename(columns={0: "vals"})
    df.plot.line(title=str(p).split("/")[-1])

# %%
def prepare_df(idx, path):
    df = pd.read_csv(str(path), header=None, delim_whitespace=idx in files_fix)
    if idx in files_fix: df = df.T
    
    df = df.rename(columns={0: "vals"})
    return df
