# %%
# %run inference__1_loading.ipynb

# %%
train_files
# Out:
# [PosixPath('/home/paulo/Documents/mba_tcc/data/2_final/0__train/001_UCR_Anomaly_DISTORTED1sddb40_35000_52000_52620.parquet'),
#  PosixPath('/home/paulo/Documents/mba_tcc/data/2_final/0__train/002_UCR_Anomaly_DISTORTED2sddb40_35000_56600_56900.parquet'),
#  PosixPath('/home/paulo/Documents/mba_tcc/data/2_final/0__train/003_UCR_Anomaly_DISTORTED3sddb40_35000_46600_46900.parquet'),
#  PosixPath('/home/paulo/Documents/mba_tcc/data/2_final/0__train/004_UCR_Anomaly_DISTORTEDBIDMC1_2500_5400_5600.parquet'),
#  PosixPath('/home/paulo/Documents/mba_tcc/data/2_final/0__train/005_UCR_Anomaly_DISTORTEDCIMIS44AirTemperature1_4000_5391_5392.parquet'),
#  PosixPath('/home/paulo/Documents/mba_tcc/data/2_final/0__train/006_UCR_Anomaly_DISTORTEDCIMIS44AirTemperature2_4000_5703_5727.parquet'),
#  PosixPath('/home/paulo/Documents/mba_tcc/data/2_final/0__train/007_UCR_Anomaly_DISTORTEDCIMIS44AirTemperature3_4000_6520_6544.parquet'),
# ...
